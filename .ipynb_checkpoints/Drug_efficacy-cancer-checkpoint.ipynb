# %% [markdown]
# # Drug efficacy

# %% [markdown]
# **Computes the change in network relative entropy from viral PPIs after setting drug state to high abundance**

# %%
import os, sys
import numpy as np
import scipy as sp
import pandas as pd
import copy as copy
from tqdm.notebook import tqdm
import math
import scipy.stats as st

from CoRe import reader
from CoRe.ncip import ncip
from CoRe.BA_C import BA

import importlib

import networkx as nx
import matplotlib.pyplot as plt
import json

from matplotlib import cm
from matplotlib import rcParams
import matplotlib.patches as patches

# %%
data_directory = "./Examples/Universal"
os.chdir(data_directory)

edge_data = pd.read_pickle('Universal_medium-PPI-edges.pkl')
node_data = pd.read_pickle('Universal_medium-PPI-nodes.pkl')

# %%
remake_graph = False

if remake_graph==False:
    netObj = ncip()
    netObj.load_graph('Universal-medium-PPI.gml')
else:
    netObj = ncip()
    netObj.load_data(edge_data,node_data)
    netObj.make_graph()
    netObj.save_network(pathway_nametag,network_type)

# %% [markdown]
# **Drugs that are part of the immune system in the Reactome database**

# %%
drugs = []
drug_names = []

all_nodes = netObj.G_d.nodes(data=True)

for n in netObj.G_d.nodes(data=True):
    if 'Drug' in n[1]['class'] and 'lat' not in n[1]['name'] and n[0] not in drug_names:
        print(n[0],n[1]['name'],n[1]['class'])
        drugs.append((n[0],n[1]['class'],n[1]['name']))
        drug_names.append(n[0])
# Out:
# R-ALL-9755995 lerociclib [nucleoplasm] ChemicalDrug
# R-ALL-9756003 trilaciclib [nucleoplasm] ChemicalDrug
# R-ALL-9755163 dalpiciclib [nucleoplasm] ChemicalDrug
# R-ALL-9754456 palbociclib [nucleoplasm] ChemicalDrug
# R-ALL-9754591 riviciclib [nucleoplasm] ChemicalDrug
# R-ALL-9754453 ribociclib [nucleoplasm] ChemicalDrug
# R-ALL-9754472 dinaciclib [nucleoplasm] ChemicalDrug
# R-ALL-9754143 abemaciclib [nucleoplasm] ChemicalDrug
# R-ALL-9756198 voruciclib [nucleoplasm] ChemicalDrug
# R-ALL-9755462 fascaplysin [nucleoplasm] ChemicalDrug
# R-ALL-9756029 PF-06873600 [nucleoplasm] ChemicalDrug
# R-ALL-9754349 RGB-286638 [nucleoplasm] ChemicalDrug
# R-ALL-9754586 RO-0505124 [nucleoplasm] ChemicalDrug
# R-ALL-9754334 R547 [nucleoplasm] ChemicalDrug
# R-ALL-9754236 alvocidib [nucleoplasm] ChemicalDrug
# R-ALL-9754583 RO-0506220 [nucleoplasm] ChemicalDrug
# R-ALL-9756042 milciclib [nucleoplasm] ChemicalDrug
# R-ALL-9755133 K00024 [nucleoplasm] ChemicalDrug
# R-ALL-9714163 dimethyl fumarate [cytosol] ChemicalDrug
# R-ALL-9712246 sulforaphane [cytosol] ChemicalDrug
# R-ALL-9714165 monomethyl fumarate [cytosol] ChemicalDrug
# R-ALL-9678957 ciclesonide [cytosol] ChemicalDrug
# R-ALL-9717033 deflazacort [cytosol] ChemicalDrug
# R-ALL-9714285 methylprednisolone [cytosol] ChemicalDrug
# R-ALL-9714305 betamethasone [cytosol] ChemicalDrug
# R-ALL-9678982 triamcinolone acetonide [cytosol] ChemicalDrug
# R-ALL-9660774 budesonide [cytosol] ChemicalDrug
# R-ALL-9717024 rimexolone [cytosol] ChemicalDrug
# R-ALL-9714304 diflorasone diacetate [cytosol] ChemicalDrug
# R-ALL-9714309 mometasone [cytosol] ChemicalDrug
# R-ALL-9717028 clobetasol propionate [cytosol] ChemicalDrug
# R-ALL-9714308 fluocinonide [cytosol] ChemicalDrug
# R-ALL-9714299 beclometasone [cytosol] ChemicalDrug
# R-ALL-9660765 PREDN [cytosol] ChemicalDrug
# R-ALL-9678975 fluticasone propionate [cytosol] ChemicalDrug
# R-ALL-9714300 flunisolide [cytosol] ChemicalDrug
# R-ALL-9660916 PREDL [cytosol] ChemicalDrug
# R-ALL-9660917 DEXA [cytosol] ChemicalDrug
# R-ALL-9714289 desoximetasone [cytosol] ChemicalDrug
# R-ALL-9679094 triamcinolone [cytosol] ChemicalDrug
# R-ALL-9714288 fluorometholone [cytosol] ChemicalDrug
# R-ALL-9678865 difluprednate [cytosol] ChemicalDrug
# R-ALL-9714292 fluocinolone acetonide [cytosol] ChemicalDrug
# R-ALL-9678963 cortisol [cytosol] ChemicalDrug
# R-ALL-9679789 belinostat [nucleoplasm] ChemicalDrug
# R-ALL-9679755 vorinostat [nucleoplasm] ChemicalDrug
# R-ALL-9679799 romidepsin [nucleoplasm] ChemicalDrug
# R-ALL-9732581 valproic acid [nucleoplasm] ChemicalDrug
# R-ALL-9679810 panobinostat [nucleoplasm] ChemicalDrug
# R-ALL-9680440 ripasudil [cytosol] ChemicalDrug
# R-ALL-9686545 netarsudil [cytosol] ChemicalDrug
# R-ALL-265479 ezetimibe [extracellular region] ChemicalDrug
# R-ALL-9714105 5-Methoxypsoralen [nucleoplasm] ChemicalDrug
# R-ALL-9714104 Trimethylpsoralen [nucleoplasm] ChemicalDrug
# R-ALL-9713841 8-Methoxypsoralen [nucleoplasm] ChemicalDrug
# R-ALL-9736537 fotemustine [nucleoplasm] ChemicalDrug
# R-ALL-9736528 carmustine [nucleoplasm] ChemicalDrug
# R-ALL-9736534 nimustine [nucleoplasm] ChemicalDrug
# R-ALL-9736533 lomustine [nucleoplasm] ChemicalDrug
# R-ALL-9714122 SG2000 [nucleoplasm] ChemicalDrug
# R-ALL-9714118 tesirine [nucleoplasm] ChemicalDrug
# R-ALL-9714119 talirine [nucleoplasm] ChemicalDrug
# R-ALL-9736547 altretamine [nucleoplasm] ChemicalDrug
# R-ALL-9736544 thioTEPA [nucleoplasm] ChemicalDrug
# R-ALL-9713798 mitomycin C [nucleoplasm] ChemicalDrug
# R-ALL-9713787 mechlorethamine [nucleoplasm] ChemicalDrug
# R-ALL-9713784 ifosfamide [nucleoplasm] ChemicalDrug
# R-ALL-9713790 melphalan [nucleoplasm] ChemicalDrug
# R-ALL-9713794 cyclophosphamide [nucleoplasm] ChemicalDrug
# R-ALL-9713792 uramustine [nucleoplasm] ChemicalDrug
# R-ALL-9713796 chlorambucil [nucleoplasm] ChemicalDrug
# R-ALL-9729899 dacarbazine [nucleoplasm] ChemicalDrug
# R-ALL-9729906 streptozocin [nucleoplasm] ChemicalDrug
# R-ALL-9729904 temozolomide [nucleoplasm] ChemicalDrug
# R-ALL-9729895 procarbazine [nucleoplasm] ChemicalDrug
# R-ALL-9679737 natalizumab [extracellular region] ProteinDrug
# R-ALL-9603260 desirudin [extracellular region] ProteinDrug
# R-ALL-9603269 bivalirudin [extracellular region] ProteinDrug
# R-ALL-9603268 lepirudin [extracellular region] ProteinDrug
# R-ALL-9015346 dabigatran [extracellular region] ChemicalDrug
# R-ALL-9603271 argatroban [extracellular region] ChemicalDrug
# R-ALL-9603697 DUP-714 [extracellular region] ChemicalDrug
# R-ALL-9603683 melagatran [extracellular region] ChemicalDrug
# R-ALL-9693043 danaparoid [plasma membrane] ChemicalDrug
# R-ALL-9693047 dalteparin [plasma membrane] ChemicalDrug
# R-ALL-9693044 tinzaparin [plasma membrane] ChemicalDrug
# R-ALL-9693067 heparin [plasma membrane] ChemicalDrug
# R-ALL-9693050 enoxaparin [plasma membrane] ChemicalDrug
# R-ALL-9693054 fondaparinux [plasma membrane] ChemicalDrug
# R-ALL-9038742 edoxaban [extracellular region] ChemicalDrug
# R-ALL-9015055 rivaroxaban [extracellular region] ChemicalDrug
# R-ALL-9603671 eribaxaban [extracellular region] ChemicalDrug
# R-ALL-9038732 apixaban [extracellular region] ChemicalDrug
# R-ALL-9038746 betrixaban [extracellular region] ChemicalDrug
# R-ALL-9681784 anakinra [extracellular region] ProteinDrug
# R-ALL-9681764 isunakinra [extracellular region] ProteinDrug
# R-ALL-9678829 baricitinib [cytosol] ChemicalDrug
# R-ALL-9678779 tofacitinib [cytosol] ChemicalDrug
# R-ALL-9678901 ibrutinib [cytosol] ChemicalDrug
# R-ALL-9678960 acalabrutinib [cytosol] ChemicalDrug
# R-ALL-9678786 ruxolitinib [cytosol] ChemicalDrug
# R-ALL-9715049 sarilumab [extracellular region] ProteinDrug
# R-ALL-9715070 satralizumab [extracellular region] ProteinDrug
# R-ALL-9681301 tocilizumab [extracellular region] ProteinDrug
# R-ALL-9679801 amlexanox [cytosol] ChemicalDrug
# R-ALL-9724689 omalizumab [extracellular region] ProteinDrug
# R-ALL-9678991 tacrolimus [cytosol] ChemicalDrug
# R-ALL-9679471 camrelizumab [extracellular region] ProteinDrug
# R-ALL-9679434 cemiplimab [extracellular region] ProteinDrug
# R-ALL-9679411 nivolumab [extracellular region] ProteinDrug
# R-ALL-9678628 HCQ [cytosol] ChemicalDrug
# R-ALL-9717004 delgocitinib [cytosol] ChemicalDrug
# R-ALL-9010792 DCA [mitochondrial matrix] ChemicalDrug
# R-ALL-9013543 sulfanegen [mitochondrial matrix] ChemicalDrug
# R-ALL-9678847 mycophenolic acid [cytosol] ChemicalDrug
# R-ALL-9679095 thioguanine [cytosol] ChemicalDrug
# R-ALL-9680963 RBV [cytosol] ChemicalDrug
# R-ALL-9035047 dicumarol [cytosol] ChemicalDrug
# R-ALL-9035044 phenindione [cytosol] ChemicalDrug
# R-ALL-9603374 acenocoumarol [cytosol] ChemicalDrug
# R-ALL-9035040 phenprocoumon [cytosol] ChemicalDrug
# R-ALL-9014945 warfarin [cytosol] ChemicalDrug
# R-ALL-76455 DEXT [endoplasmic reticulum lumen] ChemicalDrug
# R-ALL-39703 DEXM [endoplasmic reticulum lumen] ChemicalDrug
# R-ALL-9716731 lumiracoxib [cytosol] ChemicalDrug
# R-ALL-9716713 valdecoxib [cytosol] ChemicalDrug
# R-ALL-9716728 carprofen [cytosol] ChemicalDrug
# R-ALL-9716734 benzquinamide [cytosol] ChemicalDrug
# R-ALL-9716716 rofecoxib [cytosol] ChemicalDrug
# R-ALL-9716732 etoricoxib [cytosol] ChemicalDrug
# R-ALL-9716723 celecoxib [cytosol] ChemicalDrug
# R-ALL-9716725 etodolac [cytosol] ChemicalDrug
# R-ALL-9619016 spirapril [endoplasmic reticulum lumen] ChemicalDrug
# R-ALL-9619019 imidapril [endoplasmic reticulum lumen] ChemicalDrug
# R-ALL-9619015 trandolapril [endoplasmic reticulum lumen] ChemicalDrug
# R-ALL-9707110 moexipril [endoplasmic reticulum lumen] ChemicalDrug
# R-ALL-9619043 quinapril [endoplasmic reticulum lumen] ChemicalDrug
# R-ALL-9619010 zofenopril [endoplasmic reticulum lumen] ChemicalDrug
# R-ALL-9619005 benazepril [endoplasmic reticulum lumen] ChemicalDrug
# R-ALL-9619007 ramipril [endoplasmic reticulum lumen] ChemicalDrug
# R-ALL-9619006 perindopril [endoplasmic reticulum lumen] ChemicalDrug
# R-ALL-9619030 cilazapril [endoplasmic reticulum lumen] ChemicalDrug
# R-ALL-9619057 fosinopril [endoplasmic reticulum lumen] ChemicalDrug
# R-ALL-9707124 temocapril [endoplasmic reticulum lumen] ChemicalDrug
# R-ALL-9619058 enalapril [endoplasmic reticulum lumen] ChemicalDrug
# R-ALL-9614909 lisinopril [extracellular region] ChemicalDrug
# R-ALL-9707120 delapril diacid [extracellular region] ChemicalDrug
# R-ALL-9614832 captopril [extracellular region] ChemicalDrug
# R-ALL-9684077 digitoxin [extracellular region] ChemicalDrug
# R-ALL-9684057 acetyldigitoxin [extracellular region] ChemicalDrug
# R-ALL-9684074 digoxin [extracellular region] ChemicalDrug
# R-ALL-9684069 deslanoside [extracellular region] ChemicalDrug
# R-ALL-9684082 ouabain [extracellular region] ChemicalDrug
# R-ALL-9634956 pyridostigmine [extracellular region] ChemicalDrug
# R-ALL-9635036 echothiophate [extracellular region] ChemicalDrug
# R-ALL-9634973 neostigmine [extracellular region] ChemicalDrug
# R-ALL-9635021 edrophonium [extracellular region] ChemicalDrug
# R-ALL-9635054 rivastigmine [extracellular region] ChemicalDrug
# R-ALL-9635055 galanthamine [extracellular region] ChemicalDrug
# R-ALL-9635003 pralidoxime [extracellular region] ChemicalDrug
# R-ALL-9635029 physostigmine [extracellular region] ChemicalDrug
# R-ALL-9635024 tacrine [extracellular region] ChemicalDrug
# R-ALL-9635088 donepezil [extracellular region] ChemicalDrug
# R-ALL-9679750 opicapone [extracellular region] ChemicalDrug
# R-ALL-9679856 tolcapone [extracellular region] ChemicalDrug
# R-ALL-9679840 entacapone [extracellular region] ChemicalDrug
# R-ALL-2672379 amiloride [extracellular region] ChemicalDrug
# R-ALL-9692538 chlorpheniramine [extracellular region] ChemicalDrug
# R-ALL-9692535 diphenhydramine [extracellular region] ChemicalDrug
# R-ALL-9728953 DEXM [extracellular region] ChemicalDrug
# R-ALL-9692740 famotidine [extracellular region] ChemicalDrug
# R-ALL-9690591 CQ [extracellular region] ChemicalDrug
# R-ALL-9654039 haloperidol [extracellular region] ChemicalDrug
# R-ALL-1227677 Canertinib [cytosol] ChemicalDrug
# R-ALL-9652364 AEE788 [cytosol] ChemicalDrug
# R-ALL-1216527 neratinib [cytosol] ChemicalDrug
# R-ALL-1216521 Lapatinib [cytosol] ChemicalDrug
# R-ALL-9646810 Tesevatinib [cytosol] ChemicalDrug
# R-ALL-9649894 Sapitinib [cytosol] ChemicalDrug
# R-ALL-9649879 AZ5104 [cytosol] ChemicalDrug
# R-ALL-1220577 Afatinib [cytosol] ChemicalDrug
# R-ALL-9649889 CP-724714 [cytosol] ChemicalDrug
# R-ALL-9674072 crenolanib [cytosol] ChemicalDrug
# R-ALL-9616920 pazopanib [cytosol] ChemicalDrug
# R-ALL-9671491 avapritinib [cytosol] ChemicalDrug
# R-ALL-2023393 lenvatinib [cytosol] ChemicalDrug
# R-ALL-9669720 sunitinib [cytosol] ChemicalDrug
# R-ALL-2077524 masitinib [cytosol] ChemicalDrug
# R-ALL-9657514 regorafenib [cytosol] ChemicalDrug
# R-ALL-9616923 nintedanib [cytosol] ChemicalDrug
# R-ALL-9669723 dasatinib [cytosol] ChemicalDrug
# R-ALL-9669716 nilotinib [cytosol] ChemicalDrug
# R-ALL-9657029 sorafenib [cytosol] ChemicalDrug
# R-ALL-9669717 ponatinib [cytosol] ChemicalDrug
# R-ALL-9669719 axitinib [cytosol] ChemicalDrug
# R-ALL-9659761 imatinib [cytosol] ChemicalDrug
# R-ALL-9674322 ripretinib [cytosol] ChemicalDrug
# R-ALL-9656767 L-739,750 [cytosol] ChemicalDrug
# R-ALL-9656763 FTI 276 [cytosol] ChemicalDrug
# R-ALL-9656772 LB42908 [cytosol] ChemicalDrug
# R-ALL-9656770 L-778123 [cytosol] ChemicalDrug
# R-ALL-9656754 BMS-214662 [cytosol] ChemicalDrug
# R-ALL-9647938 tipifarnib [cytosol] ChemicalDrug
# R-ALL-9653475 lonafarnib [cytosol] ChemicalDrug
# R-ALL-9647934 Palmostatin B [cytosol] ChemicalDrug
# R-ALL-9657557 MK-8353 [cytosol] ChemicalDrug
# R-ALL-9657543 SCH772984 [cytosol] ChemicalDrug
# R-ALL-9657530 binimetinib [cytosol] ChemicalDrug
# R-ALL-9657527 cobimetinib [cytosol] ChemicalDrug
# R-ALL-9657517 refametinib [cytosol] ChemicalDrug
# R-ALL-9657563 Cl-1040 [cytosol] ChemicalDrug
# R-ALL-9657511 selumetinib [cytosol] ChemicalDrug
# R-ALL-9657553 PD 0325901 [cytosol] ChemicalDrug
# R-ALL-9657523 pimasertib [cytosol] ChemicalDrug
# R-ALL-9657533 VTX-11e [cytosol] ChemicalDrug
# R-ALL-9657520 ravoxertinib [cytosol] ChemicalDrug
# R-ALL-9657506 ulixertinib [cytosol] ChemicalDrug
# R-ALL-9653120 trametinib [cytosol] ChemicalDrug
# R-ALL-9657549 RO 5126766 [cytosol] ChemicalDrug
# R-ALL-9657560 GDC-0623 [cytosol] ChemicalDrug
# R-ALL-9657536 TAK-632 [cytosol] ChemicalDrug
# R-ALL-9653105 LY3009120 [cytosol] ChemicalDrug
# R-ALL-9657539 TAK-580 [cytosol] ChemicalDrug
# R-ALL-9669718 cabozantinib [cytosol] ChemicalDrug
# R-ALL-1839035 dovitinib [cytosol] ChemicalDrug
# R-ALL-2038921 midostaurin [cytosol] ChemicalDrug
# R-ALL-9678687 sirolimus [cytosol] ChemicalDrug
# R-ALL-9679464 ranibizumab [extracellular region] ProteinDrug
# R-ALL-9679482 brolucizumab [extracellular region] ProteinDrug
# R-ALL-9679463 pegaptanib [extracellular region] ChemicalDrug
# R-ALL-9679458 bevacizumab [extracellular region] ProteinDrug
# R-ALL-9679475 aflibercept [extracellular region] ProteinDrug
# R-ALL-9679469 vanucizumab [extracellular region] ProteinDrug
# R-ALL-9679474 abicipar pegol [extracellular region] ProteinDrug
# R-ALL-9734123 ARGX-111 [extracellular region] ProteinDrug
# R-ALL-9734092 emibetuzumab [extracellular region] ProteinDrug
# R-ALL-9734068 onartuzumab [extracellular region] ProteinDrug
# R-ALL-9734076 SAIT301 [extracellular region] ProteinDrug
# R-ALL-9735983 savolitinib [cytosol] ChemicalDrug
# R-ALL-9735951 PHA-665752 [cytosol] ChemicalDrug
# R-ALL-9699597 crizotinib [cytosol] ChemicalDrug
# R-ALL-9700418 foretinib [cytosol] ChemicalDrug
# R-ALL-9735969 glesatinib [cytosol] ChemicalDrug
# R-ALL-9735961 BMS-777607 [cytosol] ChemicalDrug
# R-ALL-9735960 AMG-337 [cytosol] ChemicalDrug
# R-ALL-9735966 SGX-523 [cytosol] ChemicalDrug
# R-ALL-9735987 tepotinib [cytosol] ChemicalDrug
# R-ALL-9735954 capmatinib [cytosol] ChemicalDrug
# R-ALL-9735991 MK-2461 [cytosol] ChemicalDrug
# R-ALL-9735990 golvatinib [cytosol] ChemicalDrug
# R-ALL-9735956 SU11274 [cytosol] ChemicalDrug
# R-ALL-9735985 amuvatinib [cytosol] ChemicalDrug
# R-ALL-9735957 tivantinib [cytosol] ChemicalDrug
# R-ALL-9735989 OMO-1 [cytosol] ChemicalDrug
# R-ALL-9684602 montelukast [extracellular region] ChemicalDrug
# R-ALL-9684613 zafirlukast [extracellular region] ChemicalDrug
# R-ALL-9684609 pranlukast [extracellular region] ChemicalDrug
# R-ALL-9684605 sulukast [extracellular region] ChemicalDrug
# R-ALL-9684600 SR2640 [extracellular region] ChemicalDrug
# R-ALL-9684632 pobilukast [extracellular region] ChemicalDrug
# R-ALL-9684633 MK-571 [extracellular region] ChemicalDrug
# R-ALL-9684617 verlukast [extracellular region] ChemicalDrug
# R-ALL-9684649 iralukast [extracellular region] ChemicalDrug
# R-ALL-9684629 BAYu9773 [extracellular region] ChemicalDrug
# R-ALL-9678808 fingolimod [extracellular region] ChemicalDrug
# R-ALL-9678745 siponimod [extracellular region] ChemicalDrug
# R-ALL-9717015 ozanimod [extracellular region] ChemicalDrug
# R-ALL-9702330 ASP-3026 [cytosol] ChemicalDrug
# R-ALL-9702329 AZD3463 [cytosol] ChemicalDrug
# R-ALL-9699608 alectinib [cytosol] ChemicalDrug
# R-ALL-9702130 entrectinib [cytosol] ChemicalDrug
# R-ALL-9699602 ceritinib [cytosol] ChemicalDrug
# R-ALL-9699601 brigatinib [cytosol] ChemicalDrug
# R-ALL-9699607 NVP-TAE684 [cytosol] ChemicalDrug
# R-ALL-9615293 losartan [extracellular region] ChemicalDrug
# R-ALL-9615294 olmesartan [extracellular region] ChemicalDrug
# R-ALL-9615288 telmisartan [extracellular region] ChemicalDrug
# R-ALL-9615301 eprosartan [extracellular region] ChemicalDrug
# R-ALL-9615735 forasartan [extracellular region] ChemicalDrug
# R-ALL-9615287 irbesartan [extracellular region] ChemicalDrug
# R-ALL-9615297 candesartan [extracellular region] ChemicalDrug
# R-ALL-9615299 valsartan [extracellular region] ChemicalDrug
# R-ALL-9611341 cangrelor [extracellular region] ChemicalDrug
# R-ALL-9611320 R-138727 [extracellular region] ChemicalDrug
# R-ALL-9611258 ticlopidine [extracellular region] ChemicalDrug
# R-ALL-9611274 clopidogrel [extracellular region] ChemicalDrug
# R-ALL-9611252 ticagrelor [extracellular region] ChemicalDrug
# R-ALL-9610989 atenolol [extracellular region] ChemicalDrug
# R-ALL-9610988 acebutolol [extracellular region] ChemicalDrug
# R-ALL-9618318 practolol [extracellular region] ChemicalDrug
# R-ALL-9608430 carvedilol [extracellular region] ChemicalDrug
# R-ALL-9610985 sotalol [extracellular region] ChemicalDrug
# R-ALL-9610984 levobetaxolol [extracellular region] ChemicalDrug
# R-ALL-9618315 cicloprolol [extracellular region] ChemicalDrug
# R-ALL-9610987 nebivolol [extracellular region] ChemicalDrug
# R-ALL-9610982 nadolol [extracellular region] ChemicalDrug
# R-ALL-9611007 labetalol [extracellular region] ChemicalDrug
# R-ALL-9611001 esmolol [extracellular region] ChemicalDrug
# R-ALL-9611674 pindolol [extracellular region] ChemicalDrug
# R-ALL-9611002 bupranolol [extracellular region] ChemicalDrug
# R-ALL-9610992 levobunolol [extracellular region] ChemicalDrug
# R-ALL-9608432 propranolol [extracellular region] ChemicalDrug
# R-ALL-9610994 betaxolol [extracellular region] ChemicalDrug
# R-ALL-9608434 metoprolol [extracellular region] ChemicalDrug
# R-ALL-9611838 mirabegron [extracellular region] ChemicalDrug
# R-ALL-9624761 vibegron [extracellular region] ChemicalDrug
# R-ALL-9611841 solabegron [extracellular region] ChemicalDrug
# R-ALL-9737774 lomitapide [endoplasmic reticulum lumen] ChemicalDrug
# R-ALL-349405 torcetrapib [extracellular region] ChemicalDrug
# R-ALL-446602 CIM [cytosol] ChemicalDrug
# R-ALL-446609 CIM [extracellular region] ChemicalDrug
# R-ALL-9612158 quinidine [extracellular region] ChemicalDrug
# R-ALL-9678941 CQ [cytosol] ChemicalDrug
# R-ALL-9690594 quinidine [cytosol] ChemicalDrug
# R-ALL-9648300 chlorpromazine [cytosol] ChemicalDrug

# %% [markdown]
# **Read differentially expressed genes**

# %%
up_genes = pd.read_csv('breast_cancer_up_genes.csv',header=None)[0].to_list()
down_genes = pd.read_csv('breast_cancer_down_genes.csv',header=None)[0].to_list()

# %% [markdown]
# **Specifying the reference state and construction of the global transition matrix**

# %%
initial_state_type = 'maxEnt'

errorname = '0.0'
rho = float(errorname)

input_bits = 1
code_length = int(2**input_bits)

max_entropy_state = (1.0/float(code_length))*np.ones(shape=(code_length,))

low_state = np.zeros(shape=(code_length,))
low_state[-1] = 1.0

high_state = np.zeros(shape=(code_length,))
high_state[0] = 1.0

if initial_state_type=='high':
    initial_state = high_state
elif initial_state_type=='low':
    initial_state = low_state
else:
    initial_state = max_entropy_state

print(high_state,low_state)

netObj.construct_C(rho,h=input_bits,neglect_modules=[])
node_list = list(netObj.G_d.nodes)
# Out:
# [1. 0.] [0. 1.]

# %% [markdown]
# **Disconnect all drugs from the network initially**

# %%
netObj.disconnect_drug_nodes()

# %% [markdown]
# **Compute the reference stationary state of the network**

# %%
initial_network_state = np.zeros(shape=(netObj.C_sparse.shape[0],1))
network_sources = {}

for n in range(0,len(node_list)):
    initial_network_state[code_length*n:code_length*(n+1),0] = initial_state
    
network_sources = []

reference_final_state, steps = netObj.get_final_state(initial_network_state,[])
reference_final_entropy = netObj.state_entropy(reference_final_state,[])
print('Reference state relative entropy: ',reference_final_entropy)
# Out:
# Reference state relative entropy:  0.0

# %% [markdown]
# **Set the SARS-CoV-2 nodes in the network to low abundance**

# %%
network_state = np.zeros(shape=(netObj.C_sparse.shape[0],1))
network_sources = []

for n in range(0,len(node_list)):
    network_state[code_length*n:code_length*(n+1),0] = initial_state
    
for up_gene in up_genes:
    try:
        i = node_list.index(up_gene)
        
        network_state[netObj.code_length*i:netObj.code_length*(i+1),0] = high_state

        if i not in network_sources:
            network_sources.append(i)
    except ValueError:
        pass
    
for down_gene in down_genes:
    try:
        i = node_list.index(down_gene)
        
        network_state[netObj.code_length*i:netObj.code_length*(i+1),0] = low_state

        if i not in network_sources:
            network_sources.append(i)
    except ValueError:
        pass

# %% [markdown]
# for k in tqdm(SARS_nodes.keys()):
#     for n in SARS_nodes[k]:
#         try:
#             i = node_list.index(n)
#
#             network_state[netObj.code_length*i:netObj.code_length*(i+1),0] = low_state
#
#             if i not in network_sources:
#                 network_sources.append(i)
#         except ValueError:
#             pass

# %% [markdown]
# **Compute stationary state of the network due to SARS-CoV-2 PPIs**

# %%
final_state, steps = netObj.get_final_state(network_state,network_sources)
cancer_state_entropy = netObj.state_entropy(final_state,network_sources,reference_final_state)

# %%
print(cancer_state_entropy)
# Out:
# 297.22389416542853

# %% [markdown]
# **Compute stationary state of the network due to SARS-CoV-2 PPIs and drugs**
#
# The drugs in the Reactome database were set to the state {1,0} to compute the stationary state, and the subsequent change in the network relative entropy.

# %%
df_H_with_drugs = pd.DataFrame()
df_H_drop_and_gain = pd.DataFrame()

df_H_with_drugs = pd.DataFrame([],columns=['Drug','Relative Entropy','Drug Type'])

df_H_drop_and_gain = pd.DataFrame([],columns=['Drug','Drop', 'Gain','Drug Type'])

# %%
for this_drug in tqdm(drugs):
    s = this_drug[0]
    additional_source_nodes = [s]
    
    netObj.load_graph('Universal-medium-PPI.gml')
    netObj.disconnect_drug_nodes(skip=s)
    
    netObj.construct_C(rho,h=input_bits)
    
    network_state = np.zeros(shape=(netObj.C_sparse.shape[0],1))
    network_sources = []
    
    for n in range(0,len(node_list)):
        network_state[code_length*n:code_length*(n+1),0] = initial_state

    for up_gene in up_genes:
        try:
            i = node_list.index(up_gene)

            network_state[netObj.code_length*i:netObj.code_length*(i+1),0] = high_state

            if i not in network_sources:
                network_sources.append(i)
        except ValueError:
            pass

    for down_gene in down_genes:
        try:
            i = node_list.index(down_gene)

            network_state[netObj.code_length*i:netObj.code_length*(i+1),0] = low_state

            if i not in network_sources:
                network_sources.append(i)
        except ValueError:
            pass
        
    for n in additional_source_nodes:
        try:
            i = node_list.index(n)

            network_state[netObj.code_length*i:netObj.code_length*(i+1),0] = high_state

            network_sources.append(i)
        except ValueError:
            pass
        
    this_state, steps = netObj.get_final_state(network_state,network_sources)
    H_with_drugs = netObj.state_entropy(this_state,network_sources,reference_final_state)
    H_drop, H_gain = netObj.entropy_drop_and_gain(this_state,final_state,reference_final_state,network_sources)
    
    drug_name = this_drug[2].split(' [')[0]
    
    df_temp = pd.DataFrame([[drug_name,H_with_drugs,this_drug[1]]],columns=['Drug','Relative Entropy','Drug Type'])
    df_H_with_drugs = pd.concat([df_H_with_drugs,df_temp],sort=False,ignore_index=True)

    df_temp = pd.DataFrame([[drug_name,H_drop,H_gain,this_drug[1]]],columns=['Drug', 'Drop', 'Gain','Drug Type'])
    df_H_drop_and_gain = pd.concat([df_H_drop_and_gain,df_temp],sort=False,ignore_index=True)

# %%
try:
    os.chdir('./counter_entropic_shift')
except OSError:
    os.mkdir('./counter_entropic_shift')
    os.chdir('./counter_entropic_shift')

# %%
df_H_with_drugs = df_H_with_drugs.sort_values(by=['Relative Entropy'],ignore_index=True)

all_tick_names = df_H_with_drugs['Drug'].to_list()
tick_names = [n.split(' [')[0] for n in all_tick_names]
data_size = len(tick_names)
x = np.linspace(1,data_size,data_size)

# %%
df_temp = pd.DataFrame([['Ref',cancer_state_entropy,'None']],columns=['Protein','Relative Entropy','Drug Type'])
df_H_with_drugs = pd.concat([df_temp,df_H_with_drugs],sort=False,ignore_index=True)

df_H_with_drugs.to_csv('cancerM-high_all_drug_shifts-'+initial_state_type+'.csv',index=False)

df_H_drop_and_gain = df_H_drop_and_gain.sort_values(by=['Drop'],ascending=False,ignore_index=True)
df_H_drop_and_gain.to_csv('cancerM-split_all_drug_shifts-'+initial_state_type+'.csv',index=False)

# %% [markdown]
# **Setup colorbar scale**

# %%
c_high = df_H_with_drugs['Relative Entropy'].to_numpy()[1:] - cancer_state_entropy
r_min, r_max = np.min(c_high), np.max(c_high)
max_r = max(abs(r_min),abs(r_max))
v_min, v_max = -abs(r_min), abs(r_min)

# %% [markdown]
# **Plot drugs ranked by their $ \Delta H_{\mathrm{ref}}(X) $**

# %%
fig, ax = plt.subplots(figsize=(8,7))

plt.scatter(df_H_with_drugs['Relative Entropy'].to_numpy()[1:],x,c=c_high,cmap=cm.seismic,vmin=v_min,vmax=v_max,marker='o',alpha=0.8,s=70)
plt.plot(cancer_state_entropy*np.ones(shape=x.shape),x,color='black',markersize=0,linewidth=4,alpha=1.0)
plt.ylim(0.7,data_size+0.3)

ax.set_yticks(np.arange(1,data_size+1))
ax.set_yticklabels(tick_names,fontsize=14,rotation=0)

plt.xlabel(r'$H_{\mathrm{ref}}(X)$ (bits)',size=20,labelpad=15)
plt.tick_params(axis='both',labelsize=20)

ax.xaxis.tick_top()
ax.xaxis.set_label_position('top') 

plt.xlim(0.99*np.min(df_H_with_drugs['Relative Entropy']),1.01*np.max(df_H_with_drugs['Relative Entropy']))

plt.plot(-10,cancer_state_entropy,lw=0,ms=6,marker='o',label=r'Drug state: $\{1,0\}$',c='black')

plt.legend(loc='lower right',frameon=True,fontsize=18,handlelength=1.0,handletextpad=0.25)

cbar = plt.colorbar(fraction=0.05,pad=0.01)

cbar.set_label(r'$\Delta H_{\mathrm{ref}}(X)$',fontsize=20,rotation=-90,labelpad=20)
cbar.ax.tick_params(labelsize=18)

plt.tight_layout()

plt.show()

# %% [markdown]
# **Plot drugs ranked by their $ \Delta H_{\mathrm{ref}}(X) $ drop component**

# %%
fig, ax = plt.subplots(figsize=(7,7))

plt.barh(x,df_H_drop_and_gain['Drop'],color='Blue',label='drop')
plt.barh(x,df_H_drop_and_gain['Gain'],color='Red',label='gain')

plt.xlabel(r'drop/gain in $\Delta H_{\mathrm{ref}}(X)$ (bits)',size=20,labelpad=15)

plt.tick_params(axis='x',labelsize=20,rotation=0)
plt.tick_params(axis='y',labelsize=20)

plt.ylim(0.5,len(df_H_drop_and_gain['Drug'])+0.5)
plt.tick_params(axis='x',labelsize=18)
plt.legend(frameon=False,fontsize=16,handlelength=1.0,handletextpad=0.25)
plt.text(-4.5,6,r'$\Delta H_{\mathrm{ref}}(X)=$',fontsize=19)
plt.text(-4.5,4.75,r'drop + gain',fontsize=19)

ax.xaxis.tick_top()
ax.xaxis.set_label_position('top') 

ax.set_yticks(np.arange(1,data_size+1))
ax.set_yticklabels(df_H_drop_and_gain['Drug'],fontsize=20,rotation=0)

plt.tight_layout()

plt.show()
